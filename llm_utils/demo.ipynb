# %%
import google.generativeai as genai
import os

# Configure the API key (replace with your actual API key)
# GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY") # or set it directly
genai.configure(api_key="AIzaSyBH2SHhYPEbJpWu3dl7XHgs8M5AIDjgIWE")

def generate_terraform_script_with_gemini(user_query):
    """
    Generates a Terraform script using the Gemini LLM based on a user's query.

    Args:
        user_query: A string representing the user's request.

    Returns:
        A string containing the generated Terraform script, or an error message.
    """

    model = genai.GenerativeModel('gemini-2.5-pro-exp-03-25')  # Use gemini-pro. You may need to change this based on the model you have access to.

    prompt = f"""
    You are a helpful assistant that generates Terraform code based on user requests.

    User request: {user_query}

    Generate the Terraform code, if the request is not related to terraform, return an error message.
    As output, provide only the Terraform code without any additional text or explanation.
    """

    try:
        response = model.generate_content(prompt)
        terraform_code = response.text.strip() #remove leading and trailing whitespace.
        return terraform_code
    except Exception as e:
        return f"An error occurred: {e}"

# Example usage
user_input = input("Enter your Terraform request: ")
terraform_code = generate_terraform_script_with_gemini(user_input)
print(terraform_code)
# Out:
# ```terraform
# # Provider Configuration (Ensure AWS provider is configured)
# provider "aws" {
#   region = "us-east-1" # Choose your desired AWS region
# }
#
# # Variables
# variable "bucket_name_prefix" {
#   description = "Prefix for the S3 bucket name (will have random suffix). Needs to be globally unique."
#   type        = string
#   default     = "my-angular-nextjs-app"
# }
#
# variable "tags" {
#   description = "Tags to apply to resources"
#   type        = map(string)
#   default = {
#     Project     = "AngularNextJSWebApp"
#     ManagedBy   = "Terraform"
#     Environment = "production" # Or "development", "staging", etc.
#   }
# }
#
# # --- S3 Bucket for Static Website Files ---
#
# resource "aws_s3_bucket" "app_bucket" {
#   # Use bucket_prefix for uniqueness if bucket name is not explicitly set
#   bucket_prefix = var.bucket_name_prefix
#   # Or use 'bucket' if you want to specify the exact name:
#   # bucket = "your-globally-unique-bucket-name"
#
#   tags = var.tags
#
#   # Prevent accidental deletion
#   lifecycle {
#     prevent_destroy = false # Set to true in production if desired
#   }
# }
#
# # Ownership controls for S3 bucket - Required for disabling ACLs (recommended)
# resource "aws_s3_bucket_ownership_controls" "app_bucket_ownership" {
#   bucket = aws_s3_bucket.app_bucket.id
#   rule {
#     object_ownership = "BucketOwnerEnforced" # Disables ACLs, recommended for new buckets
#   }
# }
#
# # Block public access settings for the S3 bucket (Access will be granted via CloudFront OAC)
# resource "aws_s3_bucket_public_access_block" "app_bucket_public_access" {
#   bucket = aws_s3_bucket.app_bucket.id
#
#   block_public_acls       = true
#   block_public_policy     = true
#   ignore_public_acls      = true
#   restrict_public_buckets = true
#
#   depends_on = [aws_s3_bucket_ownership_controls.app_bucket_ownership]
# }
#
# # --- CloudFront Origin Access Control (OAC) ---
# # Allows CloudFront to securely access the S3 bucket content
#
# resource "aws_cloudfront_origin_access_control" "app_oac" {
#   name                              = "${aws_s3_bucket.app_bucket.id}-oac"
#   description                       = "OAC for ${aws_s3_bucket.app_bucket.id}"
#   origin_access_control_origin_type = "s3"
#   signing_behavior                  = "always" # Always sign requests to S3
#   signing_protocol                  = "sigv4"  # Use SigV4 signing
# }
#
# # --- CloudFront Distribution ---
# # Serves the static content from S3 with CDN caching and HTTPS
#
# resource "aws_cloudfront_distribution" "s3_distribution" {
#   origin {
#     domain_name              = aws_s3_bucket.app_bucket.bucket_regional_domain_name # S3 Regional endpoint
#     origin_access_control_id = aws_cloudfront_origin_access_control.app_oac.id     # Use OAC
#     origin_id                = "S3-${aws_s3_bucket.app_bucket.id}"                 # Unique Origin ID
#
#     # Optional: Add custom headers if needed
#     # custom_header {
#     #   name  = "X-Custom-Header"
#     #   value = "my-value"
#     # }
#   }
#
#   enabled             = true
#   is_ipv6_enabled     = true
#   comment             = "Distribution for ${aws_s3_bucket.app_bucket.id}"
#   default_root_object = "index.html" # Entry point of your Angular/Next.js static build
#
#   # Aliases for custom domain names (optional)
#   # aliases = ["www.example.com", "example.com"]
#
#   default_cache_behavior {
#     allowed_methods  = ["GET", "HEAD", "OPTIONS"]           # Allowed HTTP methods
#     cached_methods   = ["GET", "HEAD"]                      # Methods to cache responses for
#     target_origin_id = "S3-${aws_s3_bucket.app_bucket.id}" # Matches origin_id above
#
#     # Cache policy and query string forwarding
#     # Using managed policies is often easier, e.g., "Managed-CachingOptimized"
#     # cache_policy_id = "658327ea-f89d-4fab-a63d-7e88639e58f6" # Managed-CachingOptimized
#
#     # Or define custom forwarding:
#     forwarded_values {
#       query_string = false # Don't forward query strings (unless needed)
#       headers      = ["Origin"] # Forward Origin header for CORS if necessary
#       cookies {
#         forward = "none" # Don't forward cookies
#       }
#     }
#
#     viewer_protocol_policy = "redirect-to-https" # Redirect HTTP to HTTPS
#     min_ttl                = 0
#     default_ttl            = 3600  # Cache for 1 hour by default
#     max_ttl                = 86400 # Cache for 24 hours maximum
#     compress               = true  # Enable Gzip/Brotli compression
#   }
#
#   # Price class affects performance and cost (PriceClass_100 is usually cheapest)
#   price_class = "PriceClass_100" # Options: PriceClass_100, PriceClass_200, PriceClass_All
#
#   # Restrictions (e.g., geographic restrictions)
#   restrictions {
#     geo_restriction {
#       restriction_type = "none" # No geo-restriction by default
#       # locations        = []
#     }
#   }
#
#   # Viewer certificate for HTTPS
#   viewer_certificate {
#     cloudfront_default_certificate = true # Use the default *.cloudfront.net certificate
#
#     # If using a custom domain and ACM certificate:
#     # acm_certificate_arn      = "arn:aws:acm:us-east-1:ACCOUNT_ID:certificate/CERTIFICATE_ID" # MUST be in us-east-1
#     # ssl_support_method       = "sni-only" # Recommended
#     # minimum_protocol_version = "TLSv1.2_2021" # Recommended
#   }
#
#   # Custom error response for Single Page Applications (SPA) routing
#   # Redirects common errors (like 404 Not Found) back to index.html
#   custom_error_response {
#     error_code            = 403 # Forbidden (e.g., direct access attempt denied by OAC)
#     response_code         = 200
#     response_page_path    = "/index.html"
#     error_caching_min_ttl = 10 # Cache the redirect for a short time
#   }
#   custom_error_response {
#     error_code            = 404 # Not Found
#     response_code         = 200
#     response_page_path    = "/index.html"
#     error_caching_min_ttl = 10
#   }
#
#   tags = var.tags
#
#   # Ensure OAC is created before the distribution
#   depends_on = [
#     aws_cloudfront_origin_access_control.app_oac,
#     aws_s3_bucket.app_bucket # Ensure bucket exists
#   ]
# }
#
# # --- S3 Bucket Policy ---
# # Grants the CloudFront distribution's service principal permission to GetObject
#
# resource "aws_s3_bucket_policy" "app_bucket_policy" {
#   bucket = aws_s3_bucket.app_bucket.id
#   policy = jsonencode({
#     Version = "2012-10-17",
#     Statement = [
#       {
#         Effect    = "Allow",
#         Principal = { Service = "cloudfront.amazonaws.com" },
#         Action    = "s3:GetObject",
#         Resource  = "${aws_s3_bucket.app_bucket.arn}/*", # Access to all objects in the bucket
#         Condition = {
#           # Restrict access to ONLY this specific CloudFront distribution
#           StringEquals = {
#             "AWS:SourceArn" = aws_cloudfront_distribution.s3_distribution.arn
#           }
#         }
#       }
#       # You might need s3:ListBucket if using Lambda@Edge or CloudFront Functions
#       # that need to list bucket contents, but it's generally not needed for GetObject.
#       # {
#       #   Effect    = "Allow",
#       #   Principal = { Service = "cloudfront.amazonaws.com" },
#       #   Action    = "s3:ListBucket",
#       #   Resource  = aws_s3_bucket.app_bucket.arn,
#       #   Condition = {
#       #     StringEquals = {
#       #       "AWS:SourceArn" = aws_cloudfront_distribution.s3_distribution.arn
#       #     }
#       #   }
#       # }
#     ]
#   })
#
#   # Ensure the public access block and distribution are created before applying the policy
#   depends_on = [
#     aws_s3_bucket_public_access_block.app_bucket_public_access,
#     aws_cloudfront_distribution.s3_distribution
#   ]
# }
#
# # --- Outputs ---
#
# output "s3_bucket_id" {
#   description = "The name (ID) of the S3 bucket storing the website content."
#   value       = aws_s3_bucket.app_bucket.id
# }
#
# output "s3_bucket_arn" {
#   description = "The ARN of the S3 bucket."
#   value       = aws_s3_bucket.app_bucket.arn
# }
#
# output "s3_bucket_regional_domain_name" {
#   description = "The regional domain name of the S3 bucket (used by CloudFront)."
#   value       = aws_s3_bucket.app_bucket.bucket_regional_domain_name
# }
#
# output "cloudfront_distribution_id" {
#   description = "The ID of the CloudFront distribution."
#   value       = aws_cloudfront_distribution.s3_distribution.id
# }
#
# output "cloudfront_distribution_arn" {
#   description = "The ARN of the CloudFront distribution."
#   value       = aws_cloudfront_distribution.s3_distribution.arn
# }
#
# output "cloudfront_distribution_domain_name" {
#   description = "The domain name assigned to the CloudFront distribution."
#   value       = aws_cloudfront_distribution.s3_distribution.domain_name
# }
#
# output "application_url" {
#   description = "The HTTPS URL to access the deployed application."
#   value       = "https://${aws_cloudfront_distribution.s3_distribution.domain_name}"
# }
# ```
